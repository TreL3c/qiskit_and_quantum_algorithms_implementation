# %%
from qiskit.circuit import QuantumCircuit, QuantumRegister, ClassicalRegister

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
from qiskit.circuit.library import grover_operator,MCMTGate, ZGate
from qiskit.visualization import plot_distribution
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

# %%
mcmt_eg=QuantumCircuit(3)
mcmt_eg.compose(MCMTGate(ZGate(),2,1),inplace=True) #If Qubits 0 and 1 are both $|1\rangle$, apply a Z-gate to Qubit 2.
#q0 and q1 are control and q2 is target
mcmt_eg.draw(output='mpl',style="iqp")

# %%
# The list [1, 2, 0] maps: Control 1 -> q1, Control 2 -> q2, Target -> q0. Note that diagram can be misleading.
# Don't take it literally.
mcmt_ex1=QuantumCircuit(3)
mcmt_ex1.compose(MCMTGate(ZGate(), 2, 1), [0, 2, 1], inplace=True)
mcmt_ex1.draw(output='mpl',style="iqp")

# %%
def grover_oracle(marked_states):
